# %%
from room import Room
from player import Player
from world import World
from graph import Graph
from util import opposite_dirs, Stack, Queue

import random
from ast import literal_eval

# %%
# Load world
world = World()


# You may uncomment the smaller graphs for development and testing purposes.
# map_file = "maps/test_line.txt"
# map_file = "maps/test_cross.txt"
# map_file = "maps/test_loop.txt"
# map_file = "maps/test_loop_fork.txt"
map_file = "maps/main_maze.txt"

# Loads the map into a dictionary
room_graph = literal_eval(open(map_file, "r").read())
world.load_graph(room_graph)

# Print an ASCII map
world.print_rooms()

player = Player(world.starting_room)

# Fill this out with directions to walk
# traversal_path = ['n', 'n']
traversal_path = []
visited = set()
# Out:
# #####
# #                                                                                                                                                           #
# #                                                        434       497--366--361  334--384--435  476                                                        #
# #                                                         |                   |    |              |                                                         #
# #                                                         |                   |    |              |                                                         #
# #                                              477--443  425            386--354--321  338  313  380--445--446                                              #
# #                                                    |    |              |         |    |    |    |    |                                                    #
# #                                                    |    |              |         |    |    |    |    |                                                    #
# #                                                   408  350  483  385  388  285  304  278  287--353  480                                                   #
# #                                                    |    |    |    |    |    |    |    |    |                                                              #
# #                                                    |    |    |    |    |    |    |    |    |                                                              #
# #                                    442  461  426  392--281  223--169  257  253  240  196--224  255  373                                                   #
# #                                     |    |    |         |         |    |    |    |    |         |    |                                                    #
# #                                     |    |    |         |         |    |    |    |    |         |    |                                                    #
# #                                    417  422--394--318--199--197--165--163--228  233--152  192--239--336--421                                              #
# #                                     |              |                   |              |    |                                                              #
# #                                     |              |                   |              |    |                                                              #
# #                          491  453--351  444  374--340  328--200--204  148--178  143  147--154--184  282  363  389                                         #
# #                           |         |    |                   |         |         |    |              |    |    |                                          #
# #                           |         |    |                   |         |         |    |              |    |    |                                          #
# #                          489  441  332  387  341--316  195  175--141  121--123--138--139--176  136--231--294--311--499                                    #
# #                           |    |    |    |         |    |         |    |                        |                                                         #
# #                           |    |    |    |         |    |         |    |                        |                                                         #
# #                     396--391  319  295  331  307  292--185--155  107  111--114--120  172  146  109  186--262--390--398                                    #
# #                           |    |    |    |    |              |    |    |              |    |    |    |              |                                     #
# #                           |    |    |    |    |              |    |    |              |    |    |    |              |                                     #
# #           452--428--411--324--289--250  277  208--166  140  082  102--064  101  093  132  086--095  098  245--343  487                                    #
# #                 |                   |    |         |    |    |         |    |    |    |    |         |    |                                               #
# #                 |                   |    |         |    |    |         |    |    |    |    |         |    |                                               #
# #           451--429  397  357--342--221--174  210  161  063--061  033  060  091  051  073  084  078--090--142  381--431                                    #
# #                      |                   |    |    |         |    |    |    |    |    |    |    |              |                                          #
# #                      |                   |    |    |         |    |    |    |    |    |    |    |              |                                          #
# #      492--400--399--358  352  297--207  124--112--106--079--046--017--028  037--042  056--067  075--088--125--238--293                                    #
# #                      |    |         |                             |    |    |         |         |    |    |                                               #
# #                      |    |         |                             |    |    |         |         |    |    |                                               #
# #           414--365--333--303  171--168--137  085  074  032  047--014  030  031  027--055  048--053  103  198--270--300--320                               #
# #                 |         |              |    |    |    |         |         |    |         |                             |                                #
# #                 |         |              |    |    |    |         |         |    |         |                             |                                #
# #                447  301--187--167--108--081--045--040--019--015--013--009  020--026  035--044--059--189--275--283--376  471                               #
# #                                          |                             |    |         |                             |                                     #
# #                                          |                             |    |         |                             |                                     #
# #                436  470  227--194--128--092  069--041--036--021  004  007--012--018--034--039--071--150--251  325  468                                    #
# #                 |    |              |    |    |    |         |    |    |         |         |    |              |                                          #
# #                 |    |              |    |    |    |         |    |    |         |         |    |              |                                          #
# #           465--368--284--254--205--162  100  072  076  011--003--000--001--022  024--025  052  115--160--214--246--412                                    #
# #                      |                        |         |         |    |         |    |                                                                   #
# #                      |                        |         |         |    |         |    |                                                                   #
# #           479--418--349  274--222--190--129  089  083--080  016--008  002--010  029  043--049--119--131--329--407                                         #
# #                 |                        |    |    |                   |    |    |    |         |                                                         #
# #                 |                        |    |    |                   |    |    |    |         |                                                         #
# #                463--458  379  226--225--105--104  099  058--023--006--005  038  054  077--130  219--305--330--454                                         #
# #                      |    |    |              |    |         |    |    |                        |         |                                               #
# #                      |    |    |              |    |         |    |    |                        |         |                                               #
# #           486--462  359  266--260  235--158--126  122  068--057  062  050--070--087  182--211  242  326  348                                              #
# #                 |    |                   |    |              |    |    |    |    |    |    |    |    |                                                    #
# #                 |    |                   |    |              |    |    |    |    |    |    |    |    |                                                    #
# #                367--344--230  243  180--164  135  145--113--094  065  066  116  117--170  248  286--288--498                                              #
# #                           |    |              |    |         |    |    |    |    |         |    |                                                         #
# #                           |    |              |    |         |    |    |    |    |         |    |                                                         #
# #                339--314--220--215--177--156--149  183  153--097  134  096  159  127--173  272  309--377--456                                              #
# #                 |                        |    |              |    |    |         |    |         |                                                         #
# #                 |                        |    |              |    |    |         |    |         |                                                         #
# #           482--404  258--236--216--213--209  191  188  157--110  144  179--201  212  202--249  371--430--440                                              #
# #            |              |         |         |    |         |    |    |    |    |    |                                                                   #
# #            |              |         |         |    |         |    |    |    |    |    |                                                                   #
# #           484  433--372--263  271--217  241--193  151--133--118--218  181  206  229  267--302--402--403--439                                              #
# #                           |    |         |    |         |         |         |    |                                                                        #
# #                           |    |         |    |         |         |         |    |                                                                        #
# #      494--457--355--312--299  310  327--256  203  247--234--259  252  244--232  237--370  364--401--427--474                                              #
# #                      |    |         |    |    |    |    |    |    |    |    |              |    |    |                                                    #
# #                      |    |         |    |    |    |    |    |    |    |    |              |    |    |                                                    #
# #                437--347  356  469--362  279  269  369  280  291  261  264  265--273--298--360  420  438                                                   #
# #                      |    |         |    |    |              |    |    |    |    |              |    |                                                    #
# #                      |    |         |    |    |              |    |    |    |    |              |    |                                                    #
# #                393--375  405  423--395  323  315--335--378  306  345  290  268  296--308--337  464  448--490                                              #
# #                      |    |                   |    |    |    |    |         |    |    |    |         |                                                    #
# #                      |    |                   |    |    |    |    |         |    |    |    |         |                                                    #
# #           493--478--413  432--473       410--406  346  466  415  409  322--276  382  317  383       475                                                   #
# #                      |    |                             |         |    |    |    |    |    |         |                                                    #
# #                      |    |                             |         |    |    |    |    |    |         |                                                    #
# #                     419  449--450                      472--495  488  424  459  455  416  460       496                                                   #
# #                                                         |                   |                                                                             #
# #                                                         |                   |                                                                             #
# #                                                   485--481                 467                                                                            #
# #                                                                                                                                                           #
#
# #####

# %%
def random_move():
    # Get global vars
    global traversal_path
    
    # Save previous room before moving
    prev_room = player.current_room.id

    # If there are unexplored dirs, move that way
    direction = random.choice(unexplored_dirs)
    traversal_path.append(direction)

    # Move that direction
    player.travel(direction)

    # Add new room to graph.rooms and visited
    graph.add_current_room(player.current_room.id, player.current_room.get_exits())
    visited.add(player.current_room.id)

    # Connect rooms in graph
    graph.rooms[prev_room][direction] = player.current_room.id
    graph.rooms[player.current_room.id][opposite_dirs[direction]] = prev_room

# %%
def find_nearest_unexplored_room():
    """
    Basically a breadth-first search
    """
    # Global vars
    global traversal_path
    
    # Create empty queue & enqueue starting room
    queue = Queue()
    queue.enqueue([player.current_room.id])
    
    # Create a new visited set
    bfs_visited = set()
    
    while queue.size() > 0:
        
        # dequeue the current room/path
        path = queue.dequeue()
        cur_room = path[-1]
        
        if cur_room not in bfs_visited:
            
            # Check if there is an unexplored exit
            if "?" in graph.get_neighbors(cur_room):
                # If so, return the path
                return path
            
            # Mark as visited
            bfs_visited.add(cur_room)
            
            # Add it's neighbors
            for neighbor in graph.get_neighbors(cur_room):
                # Copy to avoid reference error
                new_path = list(path)
                new_path.append(neighbor)
                queue.enqueue(new_path)

# %%
def path_to_directions(path):
    directions = []

    for i in range(len(path) - 1):
        # Get current and next room
        cur_room, next_room = path[i], path[i+1]
#         print(cur_room, next_room)

        # Iterate through keys, look for entry matching next_room
        for key in graph.rooms[cur_room]:
            if graph.rooms[cur_room][key] == next_room:
#                 print(key)
                directions.append(key)
                
    return directions

# %%
# Instantiate Graph
graph = Graph()

# Add the first room to graph and visited
graph.add_current_room(player.current_room.id, player.current_room.get_exits())
visited.add(player.current_room.id)

# %%
while len(visited) < 500:
    # Find unexplored directions
    unexplored_dirs = []
    for key in graph.rooms[player.current_room.id]:
        if graph.rooms[player.current_room.id][key] == "?":
            unexplored_dirs.append(key)
            
    # If there are unexplored dirs, make a random move
    if len(unexplored_dirs) > 0:
        random_move()
        
    # If there are no unexplored dirs, bfs
    else:
        path = find_nearest_unexplored_room()
        directions = path_to_directions(path)
        
        # Iterate through directions:
        for direction in directions:
            # add to traversal path
            traversal_path.append(direction)
            
            # move that direction
            player.travel(direction)

# %%
graph.rooms
# Out:
# {0: {'n': '?', 's': '?', 'w': 3, 'e': 1},
#  8: {'n': 0, 'w': 16},
#  16: {'e': 8},
#  4: {'s': 0},
#  1: {'n': 7, 's': '?', 'w': 0, 'e': 22},
#  2: {'n': 1, 's': 5, 'e': 10},
#  5: {'n': 2, 's': '?', 'w': 6},
#  50: {'n': 5, 's': 66, 'e': 70},
#  70: {'s': 116, 'w': 50, 'e': 87},
#  116: {'n': 70, 's': 159},
#  159: {'n': 116},
#  87: {'s': 117, 'w': 70},
#  117: {'n': 87, 's': 127, 'e': 170},
#  170: {'n': 182, 'w': 117},
#  182: {'s': 170, 'e': 211},
#  211: {'s': 248, 'w': 182},
#  248: {'n': 211, 's': 272},
#  272: {'n': 248},
#  127: {'n': 117, 's': 212, 'e': 173},
#  173: {'s': 202, 'w': 127},
#  202: {'n': 173, 's': 267, 'e': 249},
#  249: {'w': 202},
#  267: {'n': 202, 'e': 302},
#  302: {'w': 267, 'e': 402},
#  402: {'w': 302, 'e': 403},
#  403: {'w': 402, 'e': 439},
#  439: {'w': 403},
#  212: {'n': 127, 's': 229},
#  229: {'n': 212, 's': 237},
#  237: {'n': 229, 'e': 370},
#  370: {'w': 237},
#  66: {'n': 50, 's': 96},
#  96: {'n': 66, 's': 179},
#  179: {'n': 96, 's': 181, 'e': 201},
#  181: {'n': 179},
#  201: {'s': 206, 'w': 179},
#  206: {'n': 201, 's': 232},
#  232: {'n': 206, 's': 265, 'w': 244},
#  265: {'n': 232, 's': 268, 'e': 273},
#  268: {'n': 265, 's': 276},
#  276: {'n': 268, 's': 459, 'w': 322},
#  459: {'n': 276, 's': 467},
#  467: {'n': 459},
#  322: {'s': 424, 'e': 276},
#  424: {'n': 322},
#  273: {'s': 296, 'w': 265, 'e': 298},
#  298: {'w': 273, 'e': 360},
#  360: {'n': 364, 'w': 298},
#  364: {'s': 360, 'e': 401},
#  401: {'s': 420, 'w': 364, 'e': 427},
#  427: {'s': 438, 'w': 401, 'e': 474},
#  474: {'w': 427},
#  438: {'n': 427, 's': 448},
#  448: {'n': 438, 's': 475, 'e': 490},
#  490: {'w': 448},
#  475: {'n': 448, 's': 496},
#  496: {'n': 475},
#  420: {'n': 401, 's': 464},
#  464: {'n': 420},
#  296: {'n': 273, 's': 382, 'e': 308},
#  382: {'n': 296, 's': 455},
#  455: {'n': 382},
#  308: {'s': 317, 'w': 296, 'e': 337},
#  317: {'n': 308, 's': 416},
#  416: {'n': 317},
#  337: {'s': 383, 'w': 308},
#  383: {'n': 337, 's': 460},
#  460: {'n': 383},
#  244: {'s': 264, 'e': 232},
#  264: {'n': 244, 's': 290},
#  290: {'n': 264},
#  6: {'s': 62, 'w': '?', 'e': 5},
#  23: {'s': 57, 'w': '?', 'e': 6},
#  58: {'e': 23},
#  57: {'n': 23, 's': 94, 'w': 68},
#  94: {'n': 57, 's': 97, 'w': '?'},
#  97: {'n': 94, 's': 110, 'w': '?'},
#  153: {'e': 97},
#  110: {'n': 97, 's': 118, 'w': '?'},
#  157: {'e': 110},
#  118: {'n': 110, 'w': '?', 'e': 218},
#  218: {'n': 144, 's': 252, 'w': 118},
#  144: {'n': 134, 's': 218},
#  134: {'n': 65, 's': 144},
#  65: {'n': 62, 's': 134},
#  62: {'n': 6, 's': 65},
#  3: {'n': 21, 'w': 11, 'e': 0},
#  21: {'s': 3, 'w': 36},
#  36: {'w': 41, 'e': 21},
#  41: {'s': '?', 'w': 69, 'e': 36},
#  69: {'s': 72, 'e': 41},
#  72: {'n': 69, 's': 89},
#  89: {'n': 72, 's': 104},
#  104: {'n': 89, 's': 126, 'w': '?'},
#  105: {'n': 129, 'w': 225, 'e': 104},
#  225: {'w': 226, 'e': 105},
#  226: {'s': 260, 'e': 225},
#  260: {'n': 226, 'w': 266},
#  266: {'n': 379, 'e': 260},
#  379: {'s': 266},
#  129: {'s': 105, 'w': 190},
#  190: {'w': 222, 'e': 129},
#  222: {'w': 274, 'e': 190},
#  274: {'e': 222},
#  126: {'n': 104, 's': 135, 'w': 158},
#  158: {'s': 164, 'w': 235, 'e': 126},
#  235: {'e': 158},
#  164: {'n': 158, 'w': 180},
#  180: {'e': 164},
#  135: {'n': 126, 's': 149},
#  149: {'n': 135, 's': '?', 'w': 156},
#  191: {'n': 149, 's': 193},
#  193: {'n': 191, 's': 203, 'w': 241},
#  203: {'n': 193, 's': 269},
#  269: {'n': 203, 's': 315},
#  315: {'n': 269, 's': 406, 'e': 335},
#  335: {'s': 346, 'w': 315, 'e': 378},
#  378: {'s': 466, 'w': 335},
#  466: {'n': 378, 's': 472},
#  472: {'n': 466, 's': 481, 'e': 495},
#  481: {'n': 472, 'w': 485},
#  485: {'e': 481},
#  495: {'w': 472},
#  346: {'n': 335},
#  406: {'n': 315, 'w': 410},
#  410: {'e': 406},
#  241: {'s': 256, 'e': 193},
#  256: {'n': 241, 's': 279, 'w': 327},
#  279: {'n': 256, 's': 323},
#  323: {'n': 279},
#  327: {'s': 362, 'e': 256},
#  362: {'n': 327, 's': 395, 'w': 469},
#  469: {'e': 362},
#  395: {'n': 362, 'w': 423},
#  423: {'e': 395},
#  156: {'s': '?', 'w': 177, 'e': 149},
#  177: {'w': 215, 'e': 156},
#  215: {'n': '?', 'w': 220, 'e': 177},
#  243: {'s': 215},
#  220: {'n': 230, 'w': '?', 'e': 215},
#  230: {'s': 220, 'w': 344},
#  344: {'n': 359, 'w': '?', 'e': 230},
#  359: {'n': 458, 's': 344},
#  458: {'s': 359, 'w': 463},
#  463: {'n': 418, 'e': 458},
#  418: {'s': 463, 'w': '?', 'e': 349},
#  349: {'n': 284, 'w': 418},
#  284: {'n': 470, 's': 349, 'w': 368, 'e': 254},
#  470: {'s': 284},
#  254: {'w': 284, 'e': 205},
#  205: {'w': 254, 'e': 162},
#  162: {'n': 128, 'w': 205},
#  128: {'s': 162, 'w': 194, 'e': 92},
#  194: {'w': 227, 'e': 128},
#  227: {'e': 194},
#  92: {'n': 81, 's': 100, 'w': 128},
#  100: {'n': 92},
#  81: {'n': 137, 's': 92, 'w': '?', 'e': 45},
#  108: {'w': 167, 'e': 81},
#  167: {'w': 187, 'e': 108},
#  187: {'n': 303, 'w': 301, 'e': 167},
#  303: {'n': 352, 's': 187, 'w': 333},
#  352: {'s': 303},
#  333: {'n': 358, 'w': 365, 'e': 303},
#  365: {'s': 447, 'w': 414, 'e': 333},
#  414: {'e': 365},
#  447: {'n': 365},
#  358: {'n': 397, 's': 333, 'w': 399},
#  399: {'w': 400, 'e': 358},
#  400: {'w': 492, 'e': 399},
#  492: {'e': 400},
#  397: {'s': 358},
#  301: {'e': 187},
#  137: {'s': 81, 'w': 168},
#  168: {'n': 207, 'w': 171, 'e': 137},
#  171: {'e': 168},
#  207: {'s': 168, 'w': 297},
#  297: {'e': 207},
#  45: {'n': 85, 'w': 81, 'e': 40},
#  85: {'s': 45},
#  40: {'n': 74, 'w': 45, 'e': 19},
#  74: {'s': 40},
#  19: {'n': 32, 'w': 40, 'e': 15},
#  32: {'s': 19},
#  15: {'w': 19, 'e': 13},
#  13: {'n': 14, 'w': 15, 'e': '?'},
#  14: {'n': 17, 's': 13, 'w': '?'},
#  17: {'n': '?', 's': 14, 'w': 46, 'e': 28},
#  28: {'n': 60, 's': 30, 'w': 17},
#  60: {'n': 64, 's': 28},
#  64: {'n': 111, 's': 60, 'w': '?'},
#  111: {'n': 121, 's': 64, 'e': '?'},
#  121: {'n': '?', 's': 111, 'e': 123},
#  148: {'n': 163, 's': 121, 'e': '?'},
#  163: {'n': 257, 's': 148, 'w': '?', 'e': 228},
#  228: {'n': 253, 'w': 163},
#  253: {'n': 285, 's': 228},
#  285: {'s': 253},
#  165: {'n': 169, 'w': 197, 'e': 163},
#  169: {'n': 385, 's': 165, 'w': 223},
#  385: {'s': 169},
#  223: {'n': 483, 'e': 169},
#  483: {'s': 223},
#  197: {'w': 199, 'e': 165},
#  199: {'n': 281, 'w': 318, 'e': 197},
#  281: {'n': 350, 's': 199, 'w': 392},
#  350: {'n': 425, 's': 281},
#  425: {'n': 434, 's': 350},
#  434: {'s': 425},
#  392: {'n': 408, 'e': 281},
#  408: {'n': 443, 's': 392},
#  443: {'s': 408, 'w': 477},
#  477: {'e': 443},
#  318: {'s': 340, 'w': 394, 'e': 199},
#  394: {'n': 426, 'w': 422, 'e': 318},
#  426: {'s': 394},
#  422: {'n': 461, 'e': 394},
#  461: {'s': 422},
#  340: {'n': 318, 'w': 374},
#  374: {'e': 340},
#  257: {'n': 388, 's': 163},
#  388: {'n': 386, 's': 257},
#  386: {'s': 388, 'e': 354},
#  354: {'n': 361, 'w': 386, 'e': 321},
#  321: {'n': '?', 's': 304, 'w': 354},
#  304: {'n': 321, 's': 240},
#  240: {'n': 304, 's': 233},
#  233: {'n': 240, 'e': 152},
#  152: {'n': 196, 's': 147, 'w': 233},
#  147: {'n': 152, 's': 139, 'e': '?'},
#  139: {'n': 147, 'w': 138, 'e': 176},
#  138: {'n': 143, 'w': 123, 'e': 139},
#  123: {'w': 121, 'e': 138},
#  178: {'w': 148},
#  361: {'s': 354, 'w': 366},
#  366: {'w': 497, 'e': 361},
#  497: {'e': 366},
#  334: {'s': 321, 'e': 384},
#  384: {'w': 334, 'e': 435},
#  435: {'w': 384},
#  176: {'w': 139},
#  196: {'n': 278, 's': 152, 'e': 224},
#  278: {'n': 338, 's': 196},
#  338: {'s': 278},
#  224: {'n': 287, 'w': 196},
#  287: {'n': 313, 's': 224, 'e': 353},
#  353: {'n': 380, 'w': 287},
#  380: {'n': 476, 's': 353, 'e': 445},
#  445: {'s': 480, 'w': 380, 'e': 446},
#  480: {'n': 445},
#  446: {'w': 445},
#  476: {'s': 380},
#  313: {'s': 287},
#  143: {'s': 138},
#  154: {'n': 192, 'w': 147, 'e': 184},
#  192: {'s': 154, 'e': 239},
#  239: {'n': 255, 'w': 192, 'e': 336},
#  336: {'n': 373, 'w': 239, 'e': 421},
#  373: {'s': 336},
#  421: {'w': 336},
#  255: {'s': 239},
#  184: {'w': 154},
#  114: {'w': 111, 'e': 120},
#  120: {'w': 114},
#  30: {'n': 28},
#  46: {'n': 61, 'w': 79, 'e': 17},
#  79: {'w': 106, 'e': 46},
#  106: {'n': 161, 'w': 112, 'e': 79},
#  161: {'n': 166, 's': 106},
#  166: {'s': 161, 'w': 208},
#  208: {'n': 307, 'e': 166},
#  307: {'s': 208},
#  112: {'n': 210, 'w': 124, 'e': 106},
#  124: {'n': 174, 'e': 112},
#  174: {'n': 277, 's': 124, 'w': 221},
#  277: {'n': 331, 's': 174},
#  331: {'n': 387, 's': 277},
#  387: {'n': 444, 's': 331},
#  444: {'s': 387},
#  221: {'n': 250, 'w': 342, 'e': 174},
#  250: {'n': 295, 's': 221, 'w': 289},
#  295: {'n': 332, 's': 250},
#  332: {'n': 351, 's': 295},
#  351: {'n': 417, 's': 332, 'w': 453},
#  453: {'e': 351},
#  417: {'n': 442, 's': 351},
#  442: {'s': 417},
#  289: {'n': 319, 'w': 324, 'e': 250},
#  319: {'n': 441, 's': 289},
#  441: {'s': 319},
#  324: {'n': 391, 'w': 411, 'e': 289},
#  411: {'w': 428, 'e': 324},
#  428: {'s': 429, 'w': 452, 'e': 411},
#  452: {'e': 428},
#  429: {'n': 428, 'w': 451},
#  451: {'e': 429},
#  391: {'n': 489, 's': 324, 'w': 396},
#  489: {'n': 491, 's': 391},
#  491: {'s': 489},
#  396: {'e': 391},
#  342: {'w': 357, 'e': 221},
#  357: {'e': 342},
#  210: {'s': 112},
#  61: {'n': 82, 's': 46, 'w': 63},
#  82: {'n': 155, 's': 61},
#  155: {'s': 82, 'w': 185},
#  185: {'n': 195, 'w': 292, 'e': 155},
#  195: {'s': 185},
#  292: {'n': 316, 'e': 185},
#  316: {'s': 292, 'w': 341},
#  341: {'e': 316},
#  63: {'n': 140, 'e': 61},
#  140: {'s': 63},
#  33: {'s': 17},
#  47: {'e': 14},
#  479: {'e': 418},
#  367: {'n': 462, 'e': 344},
#  462: {'s': 367, 'w': 486},
#  486: {'e': 462},
#  76: {'n': 41},
#  252: {'n': 218, 's': 261},
#  261: {'n': 252, 's': 345},
#  345: {'n': 261, 's': 409},
#  409: {'n': 345, 's': 488},
#  488: {'n': 409},
#  133: {'s': 234, 'w': 151, 'e': 118},
#  151: {'n': 188, 'e': 133},
#  188: {'s': 151},
#  234: {'n': 133, 's': 280, 'w': 247, 'e': 259},
#  247: {'s': 369, 'e': 234},
#  369: {'n': 247},
#  259: {'s': 291, 'w': 234},
#  291: {'n': 259, 's': 306},
#  306: {'n': 291, 's': 415},
#  415: {'n': 306},
#  280: {'n': 234},
#  113: {'w': 145, 'e': 94},
#  145: {'s': 183, 'e': 113},
#  183: {'n': 145},
#  68: {'e': 57},
#  10: {'s': 38, 'w': 2},
#  38: {'n': 10},
#  11: {'s': 80, 'e': 3},
#  80: {'n': 11, 'w': 83},
#  83: {'s': 99, 'e': 80},
#  99: {'n': 83, 's': 122},
#  122: {'n': 99},
#  314: {'w': 339, 'e': 220},
#  339: {'s': 404, 'e': 314},
#  404: {'n': 339, 'w': 482},
#  482: {'s': 484, 'e': 404},
#  484: {'n': 482},
#  368: {'n': 436, 'w': 465, 'e': 284},
#  436: {'s': 368},
#  465: {'e': 368},
#  102: {'n': 107, 'e': 64},
#  107: {'n': 141, 's': 102},
#  141: {'s': 107, 'w': 175},
#  175: {'n': 200, 'e': 141},
#  200: {'s': 175, 'w': 328, 'e': 204},
#  328: {'e': 200},
#  204: {'w': 200},
#  9: {'s': 7, 'w': 13},
#  7: {'n': '?', 's': 1, 'e': 12},
#  22: {'w': 1},
#  209: {'n': 156, 'w': 213},
#  213: {'s': 217, 'w': 216, 'e': 209},
#  217: {'n': 213, 'w': 271},
#  271: {'s': 310, 'e': 217},
#  310: {'n': 271},
#  216: {'w': 236, 'e': 213},
#  236: {'s': 263, 'w': 258, 'e': 216},
#  263: {'n': 236, 's': 299, 'w': 372},
#  299: {'n': 263, 's': 356, 'w': 312},
#  356: {'n': 299, 's': 405},
#  405: {'n': 356, 's': 432},
#  432: {'n': 405, 's': 449, 'e': 473},
#  449: {'n': 432, 'e': 450},
#  450: {'w': 449},
#  473: {'w': 432},
#  312: {'s': 347, 'w': 355, 'e': 299},
#  355: {'w': 457, 'e': 312},
#  457: {'w': 494, 'e': 355},
#  494: {'e': 457},
#  347: {'n': 312, 's': 375, 'w': 437},
#  375: {'n': 347, 's': 413, 'w': 393},
#  393: {'e': 375},
#  413: {'n': 375, 's': 419, 'w': 478},
#  419: {'n': 413},
#  478: {'w': 493, 'e': 413},
#  493: {'e': 478},
#  437: {'e': 347},
#  372: {'w': 433, 'e': 263},
#  433: {'e': 372},
#  258: {'e': 236},
#  12: {'n': 20, 'w': 7, 'e': 18},
#  18: {'s': 24, 'w': 12, 'e': 34},
#  24: {'n': 18, 's': 29, 'e': 25},
#  29: {'n': 24, 's': 54},
#  54: {'n': 29},
#  25: {'s': 43, 'w': 24},
#  43: {'n': 25, 's': 77, 'e': 49},
#  49: {'w': 43, 'e': 119},
#  119: {'s': 219, 'w': 49, 'e': 131},
#  219: {'n': 119, 's': 242, 'e': 305},
#  242: {'n': 219, 's': 286},
#  286: {'n': 242, 's': 309, 'e': 288},
#  309: {'n': 286, 's': 371, 'e': 377},
#  377: {'w': 309, 'e': 456},
#  456: {'w': 377},
#  371: {'n': 309, 'e': 430},
#  430: {'w': 371, 'e': 440},
#  440: {'w': 430},
#  288: {'n': 326, 'w': 286, 'e': 498},
#  498: {'w': 288},
#  326: {'s': 288},
#  305: {'w': 219, 'e': 330},
#  330: {'s': 348, 'w': 305, 'e': 454},
#  454: {'w': 330},
#  348: {'n': 330},
#  131: {'w': 119, 'e': 329},
#  329: {'w': 131, 'e': 407},
#  407: {'w': 329},
#  77: {'n': 43, 'e': 130},
#  130: {'w': 77},
#  34: {'n': 35, 'w': 18, 'e': 39},
#  39: {'s': 52, 'w': 34, 'e': 71},
#  71: {'s': 115, 'w': 39, 'e': 150},
#  115: {'n': 71, 'e': 160},
#  160: {'w': 115, 'e': 214},
#  214: {'w': 160, 'e': 246},
#  246: {'n': 325, 'w': 214, 'e': 412},
#  412: {'w': 246},
#  325: {'s': 246},
#  150: {'w': 71, 'e': 251},
#  251: {'w': 150},
#  52: {'n': 39},
#  35: {'s': 34, 'e': 44},
#  44: {'n': 48, 'w': 35, 'e': 59},
#  59: {'w': 44, 'e': 189},
#  189: {'w': 59, 'e': 275},
#  275: {'w': 189, 'e': 283},
#  283: {'w': 275, 'e': 376},
#  376: {'s': 468, 'w': 283},
#  468: {'n': 376},
#  48: {'s': 44, 'e': 53},
#  53: {'n': 75, 'w': 48},
#  75: {'n': 78, 's': 53, 'e': 88},
#  88: {'s': 103, 'w': 75, 'e': 125},
#  103: {'n': 88},
#  125: {'s': 198, 'w': 88, 'e': 238},
#  198: {'n': 125, 'e': 270},
#  270: {'w': 198, 'e': 300},
#  300: {'w': 270, 'e': 320},
#  320: {'s': 471, 'w': 300},
#  471: {'n': 320},
#  238: {'n': 381, 'w': 125, 'e': 293},
#  381: {'s': 238, 'e': 431},
#  431: {'w': 381},
#  293: {'w': 238},
#  78: {'s': 75, 'e': 90},
#  90: {'n': 98, 'w': 78, 'e': 142},
#  98: {'n': 186, 's': 90},
#  186: {'s': 98, 'e': 262},
#  262: {'w': 186, 'e': 390},
#  390: {'w': 262, 'e': 398},
#  398: {'s': 487, 'w': 390},
#  487: {'n': 398},
#  142: {'n': 245, 'w': 90},
#  245: {'s': 142, 'e': 343},
#  343: {'w': 245},
#  20: {'n': 31, 's': 12, 'e': 26},
#  31: {'n': 37, 's': 20},
#  37: {'n': 91, 's': 31, 'e': 42},
#  91: {'n': 101, 's': 37},
#  101: {'s': 91},
#  42: {'n': 51, 'w': 37},
#  51: {'n': 93, 's': 42},
#  93: {'s': 51},
#  26: {'n': 27, 'w': 20},
#  27: {'s': 26, 'e': 55},
#  55: {'n': 56, 'w': 27},
#  56: {'n': 73, 's': 55, 'e': 67},
#  73: {'n': 132, 's': 56},
#  132: {'n': 172, 's': 73},
#  172: {'s': 132},
#  67: {'n': 84, 'w': 56},
#  84: {'n': 86, 's': 67},
#  86: {'n': 146, 's': 84, 'e': 95},
#  95: {'n': 109, 'w': 86},
#  109: {'n': 136, 's': 95},
#  136: {'s': 109, 'e': 231},
#  231: {'n': 282, 'w': 136, 'e': 294},
#  294: {'n': 363, 'w': 231, 'e': 311},
#  363: {'s': 294},
#  311: {'n': 389, 'w': 294, 'e': 499},
#  389: {'s': 311},
#  499: {'w': 311},
#  282: {'s': 231},
#  146: {'s': 86}}

# %%
traversal_path
# Out:
# ['s',
#  'w',
#  'e',
#  'n',
#  'n',
#  's',
#  'e',
#  's',
#  's',
#  's',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  'e',
#  'n',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  'w',
#  's',
#  'e',
#  's',
#  'e',
#  'w',
#  's',
#  'e',
#  'e',
#  'e',
#  'e',
#  'w',
#  'w',
#  'w',
#  'w',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  's',
#  'e',
#  'w',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'e',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  'n',
#  'e',
#  'n',
#  'n',
#  'e',
#  'e',
#  'e',
#  'n',
#  'e',
#  'e',
#  'e',
#  'w',
#  's',
#  's',
#  'e',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  'w',
#  'n',
#  'w',
#  'n',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  'n',
#  'n',
#  'w',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  'w',
#  'w',
#  'e',
#  's',
#  's',
#  's',
#  'w',
#  'e',
#  's',
#  'w',
#  'e',
#  's',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'e',
#  'n',
#  'n',
#  'w',
#  's',
#  'w',
#  'e',
#  'n',
#  'n',
#  's',
#  'w',
#  'n',
#  'w',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  'w',
#  'w',
#  'w',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  'n',
#  'e',
#  'e',
#  'n',
#  'w',
#  'w',
#  'w',
#  'e',
#  'e',
#  'e',
#  's',
#  'e',
#  's',
#  'w',
#  'w',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  'e',
#  'e',
#  's',
#  's',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  'w',
#  'n',
#  'n',
#  'w',
#  's',
#  'n',
#  'w',
#  's',
#  'w',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  'w',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'n',
#  'e',
#  'n',
#  'e',
#  'n',
#  'n',
#  'w',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  'w',
#  'n',
#  'n',
#  'w',
#  'n',
#  'e',
#  'n',
#  'n',
#  's',
#  'e',
#  'e',
#  'e',
#  'n',
#  'w',
#  'w',
#  'e',
#  'e',
#  'e',
#  's',
#  'n',
#  'n',
#  'w',
#  'w',
#  'w',
#  'n',
#  'n',
#  's',
#  'w',
#  'w',
#  'w',
#  'e',
#  's',
#  'n',
#  'e',
#  'n',
#  'w',
#  'w',
#  'w',
#  'e',
#  'e',
#  'e',
#  'n',
#  's',
#  's',
#  'e',
#  's',
#  'w',
#  'e',
#  'e',
#  'e',
#  'e',
#  'n',
#  'w',
#  'w',
#  'e',
#  'n',
#  'w',
#  'e',
#  's',
#  'e',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'e',
#  'n',
#  'n',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'e',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'w',
#  'n',
#  'n',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  's',
#  'w',
#  'w',
#  'n',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  'w',
#  'e',
#  's',
#  's',
#  'e',
#  's',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  'e',
#  'e',
#  'e',
#  'n',
#  'n',
#  'n',
#  'e',
#  'e',
#  's',
#  's',
#  's',
#  'e',
#  's',
#  's',
#  'w',
#  'w',
#  'w',
#  'n',
#  'e',
#  'w',
#  'n',
#  'w',
#  'w',
#  'w',
#  'n',
#  'w',
#  'n',
#  'n',
#  'w',
#  'e',
#  's',
#  's',
#  'e',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  's',
#  'w',
#  's',
#  'w',
#  'e',
#  'n',
#  'w',
#  'w',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'e',
#  'e',
#  'e',
#  'n',
#  'w',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  's',
#  'e',
#  'e',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  'n',
#  'e',
#  'n',
#  'w',
#  'w',
#  'e',
#  'e',
#  's',
#  'e',
#  'n',
#  'e',
#  'e',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  's',
#  'e',
#  's',
#  's',
#  'e',
#  'w',
#  'w',
#  'w',
#  'w',
#  'n',
#  'e',
#  'w',
#  'n',
#  'w',
#  'n',
#  'w',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  's',
#  'w',
#  'w',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  'w',
#  'e',
#  's',
#  's',
#  'e',
#  's',
#  'e',
#  'e',
#  'e',
#  'e',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  'n',
#  'e',
#  'n',
#  'w',
#  'w',
#  'e',
#  'e',
#  's',
#  'e',
#  'n',
#  'e',
#  'e',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  's',
#  'e',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  'e',
#  'n',
#  'e',
#  'n',
#  'e',
#  's',
#  'n',
#  'e',
#  'w',
#  'w',
#  'n',
#  's',
#  's',
#  'w',
#  'n',
#  's',
#  's',
#  'w',
#  's',
#  's',
#  's',
#  'e',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'w',
#  'n',
#  'e',
#  'w',
#  'n',
#  'e',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'w',
#  'w',
#  'w',
#  'n',
#  'w',
#  'n',
#  'n',
#  'w',
#  'e',
#  's',
#  's',
#  'e',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  's',
#  'w',
#  's',
#  'w',
#  'e',
#  'n',
#  'w',
#  'w',
#  'n',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'e',
#  'e',
#  'e',
#  'n',
#  'n',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  's',
#  'e',
#  'n',
#  'n',
#  'n',
#  'e',
#  'n',
#  'w',
#  'w',
#  'e',
#  'e',
#  's',
#  'e',
#  's',
#  's',
#  's',
#  'e',
#  's',
#  'e',
#  'n',
#  'e',
#  'e',
#  'n',
#  's',
#  'e',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  's',
#  'e',
#  'w',
#  'w',
#  's',
#  'e',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'w',
#  's',
#  'e',
#  'e',
#  'w',
#  'w',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'w',
#  'w',
#  'w',
#  'w',
#  'n',
#  'n',
#  'w',
#  'n',
#  's',
#  'e',
#  's',
#  's',
#  'w',
#  'w',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  'e',
#  'n',
#  'n',
#  's',
#  's',
#  's',
#  's',
#  's',
#  'w',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'w',
#  'w',
#  'w',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  'e',
#  'n',
#  'n',
#  'n',
#  's',
#  's',
#  'w',
#  'e',
#  's',
#  'e',
#  'e',
#  's',
#  'w',
#  'w',
#  'e',
#  'e',
#  'e',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'e',
#  'e',
#  'n',
#  'n',
#  'n',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  'w',
#  'e',
#  's',
#  'e',
#  'e',
#  's',
#  's',
#  'w',
#  'n',
#  's',
#  'e',
#  's',
#  'e',
#  'n',
#  's',
#  's',
#  'w',
#  'e',
#  's',
#  'w',
#  'w',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  's',
#  'w',
#  'n',
#  'w',
#  'n',
#  'w',
#  'e',
#  's',
#  'w',
#  'e',
#  'e',
#  's',
#  'w',
#  'w',
#  'w',
#  'w',
#  'e',
#  'n',
#  'n',
#  's',
#  'w',
#  'n',
#  'n',
#  's',
#  'w',
#  'w',
#  'w',
#  'e',
#  'e',
#  'e',
#  's',
#  'w',
#  's',
#  'n',
#  'w',
#  'e',
#  'e',
#  'e',
#  's',
#  'e',
#  'e',
#  'e',
#  's',
#  's',
#  'n',
#  'w',
#  's',
#  'w',
#  'w',
#  'w',
#  's',
#  'w',
#  'w',
#  'e',
#  's',
#  'e',
#  's',
#  's',
#  'w',
#  'n',
#  'w',
#  'e',
#  's',
#  'e',
#  'e',
#  's',
#  'e',
#  'n',
#  's',
#  'e',
#  'e',
#  'e',
#  'n',
#  'n',
#  'w',
#  's',
#  'w',
#  'e',
#  'n',
#  'w',
#  'e',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  'e',
#  's',
#  'n',
#  'e',
#  'e',
#  's',
#  'e',
#  's',
#  'w',
#  'e',
#  'n',
#  'e',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'e',
#  's',
#  's',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  'e',
#  'e',
#  'e',
#  'n',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  'w',
#  'n',
#  'n',
#  'e',
#  'w',
#  'w',
#  'w',
#  's',
#  'w',
#  'w',
#  's',
#  'e',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  'n',
#  'n',
#  'n',
#  'w',
#  's',
#  's',
#  's',
#  's',
#  'n',
#  'n',
#  'w',
#  's',
#  'n',
#  'e',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'w',
#  'n',
#  'n',
#  'n',
#  'e',
#  's',
#  's',
#  'n',
#  'n',
#  'e',
#  's',
#  'e',
#  'n',
#  'e',
#  ...]

# %%
player.current_room.id
# Out:
# 146

# %%
len(graph.rooms)
# Out:
# 500

# %%
len(traversal_path)
# Out:
# 2390
